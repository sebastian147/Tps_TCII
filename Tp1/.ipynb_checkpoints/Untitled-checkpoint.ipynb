# %%
from IPython import display
display.Image("ej1.png")

# %% [markdown]
# Procedo a analizar el primer circuito
# $$\frac{v1}{v2}$$

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-86483cf2d7fa> in <module>
# ----> 1 MathJax.Hub.Config({
#       2   "HTML-CSS": {
#       3     availableFonts: ["TeX"],
#       4     preferredFont: "TeX",
#       5   }
#
# NameError: name 'MathJax' is not defined
